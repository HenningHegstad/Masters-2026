# %%
import json
import math
import os

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D


def _leaf_p_cap(reg):
    p_cap = reg.get("P_cap_leaf", None)
    if p_cap is not None:
        return int(p_cap)

    n_mu = reg.get("n_mu_train", None)
    if n_mu is None:
        return None

    n_mu = int(n_mu)
    return max(0, int(np.floor(np.sqrt(n_mu))) - 1) if n_mu > 0 else 0


def is_requested_P_valid_for_all_leaves(payload, P_value):
    regions = payload.get("pod_spectra", {}).get("regions", {})
    if not regions:
        return True

    p_req = int(P_value)
    for reg in regions.values():
        p_cap = _leaf_p_cap(reg)
        if p_cap is None:
            continue
        if p_req > p_cap:
            return False
    return True


def filter_valid_P_values(payload, P_values):
    P_values = np.asarray(P_values, dtype=int)
    if P_values.size == 0:
        return P_values
    mask = np.array([is_requested_P_valid_for_all_leaves(payload, p) for p in P_values], dtype=bool)
    return P_values[mask]


def filter_valid_P_series(payload, P_values, *arrays):
    P_values = np.asarray(P_values, dtype=int)
    if P_values.size == 0:
        outs = [P_values]
        outs.extend(np.asarray(a) for a in arrays)
        return tuple(outs)

    mask = np.array([is_requested_P_valid_for_all_leaves(payload, p) for p in P_values], dtype=bool)
    outs = [P_values[mask]]
    for arr in arrays:
        arr = np.asarray(arr)
        m = min(len(arr), len(mask))
        outs.append(arr[:m][mask[:m]])
    return tuple(outs)


def assert_requested_P_within_leaf_caps(payload, P_value):
    p_req = int(P_value)
    if is_requested_P_valid_for_all_leaves(payload, p_req):
        return p_req
    print(f"Skipping invalid/capped P={p_req} (exceeds leaf admissible degree).")
    return None


def validate_no_silent_capped_models(payload):
    # Non-failing by design: plotting code filters invalid P points explicitly.
    return


plt.rcParams.update({
    "font.family": "serif",
    # Put a guaranteed Matplotlib serif first to avoid sans fallback.
    "font.serif": ["DejaVu Serif", "CMU Serif", "Computer Modern Roman", "Latin Modern Roman"],
    "mathtext.fontset": "cm",
    "text.usetex": False,
    "font.size": 14,
    "axes.labelsize": 16,
    "axes.titlesize": 18,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
    "legend.fontsize": 12,
    "lines.linewidth": 1.8,
    "lines.markersize": 5,
})

def format_tau_math(tau):
    s = f"{tau:.15e}"
    mantissa, exponent = s.split("e")
    mantissa = mantissa.rstrip("0").rstrip(".")
    # return f"{mantissa}\\times10^{{{int(exponent)}}}"
    return f"10^{{{int(exponent)}}}"


# ----------------------------
# Load multiple runs
# ----------------------------
paths = [
    (r"$1\times 1$", "results_nsplit1.json"),
    (r"$2\times 2$", "results_nsplit2.json"),
    (r"$4\times 4$", "results_nsplit4.json"),
    (r"$8\times 8$", "results_nsplit8.json"),
]

runs = []
for name, path in paths:
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)
    validate_no_silent_capped_models(data)
    runs.append({
        "name": name,
        "cfg": data["config"],
        "results": data["results"],
        "meta": data.get("meta", {}),
        "payload": data,
    })

tau_list = [float(t) for t in runs[0]["cfg"]["tau_list"]]


def average_r_components_per_tau(run):
    out = {}
    res = run["results"]
    for tau in tau_list:
        tau_key = str(tau)
        block = res[tau_key]

        r_p_list = np.asarray(block.get("r_p", []), dtype=float)
        r_u_stab_list = np.asarray(block.get("r_u", []), dtype=float)

        if len(r_p_list) == 0 or len(r_u_stab_list) == 0:
            out[tau] = None
            continue

        # Stored r_u is stabilized velocity size (velocity + supremizers).
        # Using r_s = r_p and r_u = r_u_stab - r_s gives r = [r_p, r_u, r_s].
        r_p = float(np.mean(r_p_list))
        r_s = r_p
        r_u = float(np.mean(r_u_stab_list - r_s))

        out[tau] = (r_p, r_u, r_s)
    return out

def format_r_value(r):
    return f"{r:.2f}".rstrip("0").rstrip(".")

def format_r_triplet(vals):
    if vals is None:
        return "N/A"
    r_p, r_u, r_s = vals
    return f"[{format_r_value(r_p)},{format_r_value(r_u)},{format_r_value(r_s)}]"


# ----------------------------
# Plot helper
# ----------------------------
def plot_metric_grid(
    runs,
    tau_list,
    title,
    key_mean,
    key_max,
    ylabel,
    ylims=(1e-4, 1.0),
    savepath=None,
):
    nplots = len(runs)

    # Force 2x2 layout for 4 runs
    if nplots == 4:
        nrows, ncols = 2, 2
    else:
        ncols = min(3, nplots)
        nrows = math.ceil(nplots / ncols)

    fig, axes = plt.subplots(
        nrows, ncols,
        figsize=(4.8 * ncols, 5.2 * nrows),
        sharex=True,
        sharey=True,
        squeeze=False,
    )

    axes = axes.ravel()
    # fig.suptitle(title, fontsize=20)
    for ax in axes[nplots:]:
        ax.set_visible(False)

    for idx, (ax, run) in enumerate(zip(axes, runs)):
        results = run["results"]
        tau_to_color = {}

        for tau in tau_list:
            tau_key = str(tau)
            Pvals = np.array(results[tau_key]["P"], dtype=int)

            ymean = np.array(results[tau_key][key_mean], dtype=float)
            ymax = np.array(results[tau_key][key_max], dtype=float)
            Pvals, ymean, ymax = filter_valid_P_series(run["payload"], Pvals, ymean, ymax)
            if Pvals.size == 0:
                continue

            l_mean, = ax.semilogy(Pvals, ymean, linestyle="-", marker="o")
            color = l_mean.get_color()
            ax.semilogy(Pvals, ymax, linestyle="--", marker="o", mfc="none", color=color)

            tau_to_color[tau] = color

        ax.set_ylim(*ylims)
        ax.set_title(run["name"])
        ax.grid(True, which="major", ls="--", alpha=1.0)

        # ---- axis labeling logic ----
        row = idx // ncols
        col = idx % ncols

        if row == nrows - 1:
            ax.set_xlabel(r"Polynomial degree $P$")
        if col == 0:
            ax.set_ylabel(ylabel)

        # ---- tau legend ----
        r_dict = average_r_components_per_tau(run)
        tau_handles = []
        tau_labels = []

        is_single_domain = run["cfg"].get("Nsplit", 1) == 1

        for tau in tau_list:
            tau_handles.append(Line2D([0], [0], lw=1.8, color=tau_to_color.get(tau, "k")))
            tau_math = format_tau_math(tau)
            if is_single_domain:
                tau_labels.append(rf"$\tau={tau_math}\,(r={format_r_triplet(r_dict[tau])})$")
            else:
                tau_labels.append(rf"$\tau={tau_math}\,(r\approx {format_r_triplet(r_dict[tau])})$")

        leg_tau = ax.legend(
            tau_handles,
            tau_labels,
            loc="best",
            framealpha=0.7,
        )
        ax.add_artist(leg_tau)

        # ---- mean/max legend ----
        style_handles = [
            Line2D([0], [0], color="k", lw=1.8, linestyle="-", marker="o", label="Mean"),
            Line2D([0], [0], color="k", lw=1.4, linestyle="--", marker="o", mfc="none", label="Max"),
        ]

    style_handles = [
        Line2D([0], [0], color="k", lw=1.8, linestyle="-", marker="o", label="Mean"),
        Line2D([0], [0], color="k", lw=1.4, linestyle="--", marker="o", mfc="none", label="Max"),
    ]
    fig.legend(
        handles=style_handles,
        loc="upper center",
        ncol=2,
        frameon=True,
        fontsize=13,
        bbox_to_anchor=(0.53, 0.98),
    )

    plt.tight_layout(rect=(0, 0, 1, 0.95))

    if savepath is not None:
        fig.savefig(savepath, dpi=300, bbox_inches="tight")

    plt.show()


# ----------------------------
# Plot specs
# ----------------------------
plot_specs = [
    dict(
        title=r"Baseline ROM: max-in-time $L^2$ error of $u$",
        key_mean="baseline_u_l2_scaled_maxt_mean",
        key_max="baseline_u_l2_scaled_maxt_max",
        ylabel=r"Relative ${L}^2$ error"
    ),
    dict(
        title=r"Baseline ROM: max-in-time $L^2$ error of $p$",
        key_mean="baseline_p_l2_scaled_maxt_mean",
        key_max="baseline_p_l2_scaled_maxt_max",
        ylabel=r"Relative ${L}^2$ error"
    ),
    dict(
        title=r"CoSTA ROM: max-in-time $L^2$ error of $u$",
        key_mean="costa_u_l2_scaled_maxt_mean",
        key_max="costa_u_l2_scaled_maxt_max",
        ylabel=r"Relative ${L}^2$ error"
    ),
    dict(
        title=r"CoSTA ROM: max-in-time $L^2$ error of $p$",
        key_mean="costa_p_l2_scaled_maxt_mean",
        key_max="costa_p_l2_scaled_maxt_max",
        ylabel=r"Relative ${L}^2$ error"
    ),
    dict(
        title=r"Baseline ROM: max-in-time kHdiv error of $u$",
        key_mean="baseline_u_khdiv_scaled_maxt_mean",
        key_max="baseline_u_khdiv_scaled_maxt_max",
        ylabel=r"Relative energy error"
    ),
    dict(
        title=r"CoSTA ROM: max-in-time kHdiv error of $u$",
        key_mean="costa_u_khdiv_scaled_maxt_mean",
        key_max="costa_u_khdiv_scaled_maxt_max",
        ylabel=r"Relative energy error"
    ),
]

save_dir = "figs"
problem = "var_K_stationary"
os.makedirs(save_dir, exist_ok=True)

for i, spec in enumerate(plot_specs, start=1):
    # savepath = os.path.join(save_dir, f"{i:02d}_{spec['key_mean']}_grid_{problem}.pdf")
    savepath = os.path.join(save_dir, f"{spec['key_mean']}_grid_{problem}.pdf")

    plot_metric_grid(
        runs=runs,
        tau_list=tau_list,
        title=spec["title"],
        key_mean=spec["key_mean"],
        key_max=spec["key_max"],
        ylabel=spec["ylabel"],
        ylims=(1e-5, 1.0),
        savepath=savepath
    )

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D


def _leaf_p_cap(reg):
    p_cap = reg.get("P_cap_leaf", None)
    if p_cap is not None:
        return int(p_cap)

    n_mu = reg.get("n_mu_train", None)
    if n_mu is None:
        return None

    n_mu = int(n_mu)
    return max(0, int(np.floor(np.sqrt(n_mu))) - 1) if n_mu > 0 else 0


def is_requested_P_valid_for_all_leaves(payload, P_value):
    regions = payload.get("pod_spectra", {}).get("regions", {})
    if not regions:
        return True

    p_req = int(P_value)
    for reg in regions.values():
        p_cap = _leaf_p_cap(reg)
        if p_cap is None:
            continue
        if p_req > p_cap:
            return False
    return True


def filter_valid_P_values(payload, P_values):
    P_values = np.asarray(P_values, dtype=int)
    if P_values.size == 0:
        return P_values
    mask = np.array([is_requested_P_valid_for_all_leaves(payload, p) for p in P_values], dtype=bool)
    return P_values[mask]


def filter_valid_P_series(payload, P_values, *arrays):
    P_values = np.asarray(P_values, dtype=int)
    if P_values.size == 0:
        outs = [P_values]
        outs.extend(np.asarray(a) for a in arrays)
        return tuple(outs)

    mask = np.array([is_requested_P_valid_for_all_leaves(payload, p) for p in P_values], dtype=bool)
    outs = [P_values[mask]]
    for arr in arrays:
        arr = np.asarray(arr)
        m = min(len(arr), len(mask))
        outs.append(arr[:m][mask[:m]])
    return tuple(outs)


def assert_requested_P_within_leaf_caps(payload, P_value):
    p_req = int(P_value)
    if is_requested_P_valid_for_all_leaves(payload, p_req):
        return p_req
    print(f"Skipping invalid/capped P={p_req} (exceeds leaf admissible degree).")
    return None


def validate_no_silent_capped_models(payload):
    # Non-failing by design: plotting code filters invalid P points explicitly.
    return


# plt.rcParams.update({
#     "font.family": "serif",
#     "font.size": 14,
#     "axes.labelsize": 16,
#     "axes.titlesize": 18,
#     "xtick.labelsize": 14,
#     "ytick.labelsize": 14,
#     "legend.fontsize": 11,
#     "lines.linewidth": 1.8,
#     "lines.markersize": 5,
# })

# ----------------------------
# Load runs
# ----------------------------
paths = [
    (r"$1\times 1$", "results_nsplit1.json"),
    (r"$2\times 2$", "results_nsplit2.json"),
    (r"$4\times 4$", "results_nsplit4.json"),
    (r"$8\times 8$", "results_nsplit8.json"),
]

runs = []
for name, path in paths:
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)
    validate_no_silent_capped_models(data)

    runs.append({
        "name": name,
        "cfg": data.get("config", {}),
        "results": data.get("results", {}),
        "direct_muu_l2fit_errors": data.get("direct_muu_l2fit_errors", {}),
        "meta": data.get("meta", {}),
        "payload": data,
    })

# ----------------------------
# Metrics to overlay in each subplot
# mean key (solid) + max key (dotted)
# ----------------------------
plot_specs = [
    dict(
        mean_key="muu_over_fullA_fro_rel",
        max_key="muu_over_fullA_fro_rel_maxmu",
        label=r"$\| e_{\mathbf{A}} \|_{F}$",
        marker="o",
    ),
    dict(
        mean_key="p_l2_rel",
        max_key="p_l2_rel_maxt_maxmu",
        label=r"$\| e_p \|_{L^2(\Omega)}$",
        marker="^",
    ),
    dict(
        mean_key="u_l2_rel",
        max_key="u_l2_rel_maxt_maxmu",
        label=r"$\| e_{\mathbf{u}} \|_{L^2(\Omega)}$",
        marker="s",
    ),
    # dict(
    #     mean_key="u_hdiv_rel",
    #     max_key="u_hdiv_rel_maxt_maxmu",
    #     label=r"$\| e_u \|_{H(\mathrm{div})}$",
    #     marker="d",
    # ),
    dict(
        mean_key="u_khdiv_rel",
        max_key="u_khdiv_rel_maxt_maxmu",
        label=r"$\| e_{\mathbf{u}} \|_{E(\Omega)}$",
        marker="x",
    ),
]


# ----------------------------
# Plot helper:
# 2x2 grid, one subplot per run,
# with all error curves overlaid in each subplot
# ----------------------------
def plot_direct_fit_overlay_grid(
    runs,
    plot_specs,
    title=r"Direct $L^2$-fit errors",
    ylabel="Relative error",
    ylims=(1e-8, 1.0),
    savepath=None,
    panel_width=4.8,
    panel_height=5.2,
):
    if len(runs) != 4:
        raise ValueError("This function expects exactly 4 runs for a 2x2 grid.")

    nrows, ncols = 2, 2

    fig, axes = plt.subplots(
        nrows, ncols,
        figsize=(2 * panel_width, 2 * panel_height),
        sharex=True,
        sharey=True,
        squeeze=False,
    )
    axes = axes.ravel()

    for idx, (ax, run) in enumerate(zip(axes, runs)):
        fitres = run.get("direct_muu_l2fit_errors", {})

        ax.set_title(run["name"])
        ax.set_ylim(*ylims)
        ax.grid(True, which="major", ls="--", alpha=1.0)

        row = idx // ncols
        col = idx % ncols

        if row == nrows - 1:
            ax.set_xlabel(r"Polynomial degree $P$")

        if col == 0:
            ax.set_ylabel(ylabel)

        if not fitres:
            ax.text(
                0.5, 0.5, "No direct fit data",
                transform=ax.transAxes,
                ha="center",
                va="center",
                fontsize=13,
            )
            continue

        Pvals = np.array(sorted(int(k) for k in fitres.keys()), dtype=int)
        Pvals = filter_valid_P_values(run["payload"], Pvals)
        if Pvals.size == 0:
            ax.text(0.5, 0.5, "No valid P points", transform=ax.transAxes, ha="center", va="center", fontsize=13)
            continue

        # metric legend (color/marker = metric)
        metric_handles = []

        # overlay mean + max for each metric
        for spec in plot_specs:
            mean_key = spec["mean_key"]
            max_key = spec["max_key"]
            label = spec["label"]
            marker = spec.get("marker", "o")

            x_mean, y_mean = [], []
            x_max, y_max = [], []

            for P in Pvals:
                entry = fitres[str(P)]

                if mean_key in entry and entry[mean_key] is not None:
                    x_mean.append(P)
                    y_mean.append(float(entry[mean_key]))

                if max_key in entry and entry[max_key] is not None:
                    x_max.append(P)
                    y_max.append(float(entry[max_key]))

            if len(x_mean) == 0 and len(x_max) == 0:
                continue

            color = None
            if len(x_mean) > 0:
                line_mean, = ax.semilogy(
                    x_mean,
                    y_mean,
                    linestyle="-",
                    marker=marker,
                    label=label,
                )
                color = line_mean.get_color()
                metric_handles.append(
                    Line2D([0], [0], color=color, lw=1.8, marker=marker, linestyle="-", label=label)
                )

            if len(x_max) > 0:
                if color is None:
                    line_max, = ax.semilogy(
                        x_max,
                        y_max,
                        linestyle="--",
                        marker=marker,
                        mfc="none",
                        label=None,
                    )
                    color = line_max.get_color()
                    metric_handles.append(
                        Line2D([0], [0], color=color, lw=1.8, marker=marker, linestyle="-", label=label)
                    )
                else:
                    ax.semilogy(
                        x_max,
                        y_max,
                        linestyle="--",
                        marker=marker,
                        mfc="none",
                        color=color,
                        label=None,
                    )

        # legend 1: metrics (color/marker)
        if metric_handles:
            leg_metrics = ax.legend(handles=metric_handles, loc="lower left", frameon=True)
            ax.add_artist(leg_metrics)

        # legend 2: line style meaning
        style_handles = [
            Line2D([0], [0], color="k", lw=1.8, linestyle="-", label="Integrated"),
            Line2D([0], [0], color="k", lw=1.8, linestyle="--", label="Max"),
        ]
        ax.legend(handles=style_handles, loc="lower right", frameon=True)

    plt.tight_layout(rect=[0.03, 0.03, 1.00, 0.95])

    if savepath is not None:
        fig.savefig(savepath, dpi=300, bbox_inches="tight")

    plt.show()


# ----------------------------
# Make the single 2x2 figure
# ----------------------------
savepath = "figs/l2_fit_error.pdf"
# savepath = "direct_fit_overlay_2x2.png"

plot_direct_fit_overlay_grid(
    runs=runs,
    plot_specs=plot_specs,
    title=r"Direct $L^2$-fit errors for each domain split",
    ylabel="Relative error",
    ylims=(1e-8, 1.0),
    savepath=savepath,
    panel_width=4.8,
    panel_height=5.2,
)

# %%
from pathlib import Path
def load_payload(json_path):
    with open(json_path, "r", encoding="utf-8") as f:
        payload = json.load(f)
    return payload


def _region_sort_key(region_id):
    s = str(region_id)
    return (len(s), s)


def get_region_spectra(payload, field="u_svals_full", normalize=False):
    regions = payload.get("regions") or payload.get("pod_spectra", {}).get("regions", {})
    spectra = {}
    for region_id, meta in regions.items():
        raw = meta.get(field, [])
        s = np.asarray(raw, dtype=float)

        if s.size == 0:
            continue

        if normalize:
            s = s / max(abs(s[0]), 1e-30)

        spectra[region_id] = s

    if not spectra:
        where = 'payload["regions"] or payload["pod_spectra"]["regions"]'
        raise ValueError(f"No non-empty spectra found for field={field!r} in {where}.")

    return spectra


def truncate_spectra_to_common_length(spectra, max_modes=None):
    lengths = [len(s) for s in spectra.values()]
    common_len = min(lengths)

    if max_modes is None:
        m = common_len
    else:
        m = min(int(max_modes), common_len)

    keys_sorted = sorted(spectra.keys(), key=_region_sort_key)
    S_full = np.vstack([spectra[k][:common_len] for k in keys_sorted])

    return keys_sorted, S_full, m, common_len

def compute_discarded_energy_statistics(S):
    denom = np.sum(S**2, axis=1, keepdims=True)
    denom = np.maximum(denom, 1e-30)

    retained = np.cumsum(S**2, axis=1) / denom
    discarded = np.sqrt(np.maximum(1.0 - retained, 1e-16))

    d_min = np.min(discarded, axis=0)
    d_mean = np.mean(discarded, axis=0)
    d_max = np.max(discarded, axis=0)

    return {
        "discarded": discarded,
        "d_min": d_min,
        "d_mean": d_mean,
        "d_max": d_max,
    }


# ============================================================
# Plotter: overlay velocity + pressure discarded-energy envelopes
# ============================================================
def plot_regional_discarded_energy_grid_both(
    paths,
    fields=("u_svals_full", "p_svals_full"),
    normalize=False,
    max_modes=128,
    show_all_regions_faint=True,
    logy=True,
    panel_width=4.8,
    panel_height=5.2,
    save_pdf=True,
    pdf_path=None,
):
    if len(fields) != 2:
        raise ValueError("fields must contain exactly two entries: velocity and pressure")

    labels = {
        "u_svals_full": "Velocity",
        "p_svals_full": "Pressure",
    }

    runs = []
    for name, json_path in paths:
        payload = load_payload(json_path)

        field_data = {}
        for field in fields:
            spectra = get_region_spectra(payload=payload, field=field, normalize=normalize)
            keys_sorted, S_full, m, common_len = truncate_spectra_to_common_length(
                spectra=spectra,
                max_modes=max_modes,
            )
            stats = compute_discarded_energy_statistics(S_full)
            field_data[field] = {
                "keys_sorted": keys_sorted,
                "S_full": S_full,
                "m": m,
                "common_len": common_len,
                "stats": stats,
            }

        runs.append({
            "name": name,
            "json_path": json_path,
            "fields": field_data,
        })

    nplots = len(runs)
    if nplots == 4:
        nrows, ncols = 2, 2
    else:
        ncols = min(3, nplots)
        nrows = math.ceil(nplots / ncols)

    fig, axes = plt.subplots(
        nrows,
        ncols,
        figsize=(panel_width * ncols, panel_height * nrows),
        sharex=True,
        sharey=True,
        squeeze=False,
    )
    axes = axes.ravel()

    for ax in axes[nplots:]:
        ax.set_visible(False)

    for idx, (ax, run) in enumerate(zip(axes, runs)):
        for field in fields:
            fd = run["fields"][field]
            m_field = int(fd["m"])
            x_field = np.arange(1, m_field + 1)
            stats = fd["stats"]

            discarded = stats["discarded"][:, :m_field]
            d_min_view = stats["d_min"][:m_field]
            d_mean_view = stats["d_mean"][:m_field]
            d_max_view = stats["d_max"][:m_field]

            if show_all_regions_faint:
                for row in discarded:
                    ax.plot(x_field, row, color="0.7", alpha=0.10, linewidth=0.8)

            h_mean, = ax.plot(x_field, d_mean_view, linewidth=2.0)
            mean_color = h_mean.get_color()
            ax.fill_between(x_field, d_min_view, d_max_view, facecolor=mean_color, alpha=0.16)

        if logy:
            ax.set_yscale("log")

        ax.set_title(run["name"])
        ax.grid(True, which="major", ls="--", alpha=0.7)

        row = idx // ncols
        col = idx % ncols
        if row == nrows - 1:
            ax.set_xlabel("Number of modes $r$")
        if col == 0:
            ax.set_ylabel("Relative discarded energy")

        # if idx == 0:
        if 0 == 0:
            legend_handles = [
                Line2D([0], [0], color="C0", lw=2.0, label=f"{labels.get(fields[0], fields[0])}"),
                Line2D([0], [0], color="C1", lw=2.0, label=f"{labels.get(fields[1], fields[1])}"),
            ]
            ax.legend(handles=legend_handles, loc="upper right", frameon=True)

    title = f"Regional sqrt relative discarded energy ({fields[0]} + {fields[1]})"
    if normalize:
        title += " (normalized)"

    plt.tight_layout(rect=[0.02, 0.02, 1.00, 0.95])
    if save_pdf:
        if pdf_path is None:
            suffix = "normalized" if normalize else "raw"
            pdf_file = Path(f"figs/regional_discarded_energy_both_{suffix}.pdf")
        else:
            pdf_file = Path(pdf_path)
            if pdf_file.suffix.lower() != ".pdf":
                pdf_file = pdf_file.with_suffix(".pdf")

        pdf_file.parent.mkdir(parents=True, exist_ok=True)
        fig.savefig(pdf_file, format="pdf", bbox_inches="tight")

    plt.show()

    for run in runs:
        u = run["fields"][fields[0]]
        p = run["fields"][fields[1]]
        print(
            f"{run['name']}: "
            f"u_regions={len(u['keys_sorted'])}, p_regions={len(p['keys_sorted'])}, "
            f"u_common_modes={u['common_len']}, p_common_modes={p['common_len']}, "
            f"u_used={u['m']}, p_used={p['m']}"
        )


# ============================================================
paths = [
    (r"$1 \times 1$", "results_nsplit1.json"),
    (r"$2 \times 2$", "results_nsplit2.json"),
    (r"$4 \times 4$", "results_nsplit4.json"),
    (r"$8 \times 8$", "results_nsplit8.json"),
]

fields = ("u_svals_full", "p_svals_full")
normalize = False
max_modes = 128
show_all_regions_faint = True
logy = True
pdf_path = "figs/discarded_energy.pdf"

plot_regional_discarded_energy_grid_both(
    paths=paths,
    fields=fields,
    normalize=normalize,
    max_modes=max_modes,
    show_all_regions_faint=show_all_regions_faint,
    logy=logy,
    panel_width=4.8,
    panel_height=5.2,
    pdf_path=pdf_path,
)
# Out:
# $1 \times 1$: u_regions=1, p_regions=1, u_common_modes=200, p_common_modes=200, u_used=128, p_used=128
# $2 \times 2$: u_regions=4, p_regions=4, u_common_modes=200, p_common_modes=134, u_used=128, p_used=128
# $4 \times 4$: u_regions=16, p_regions=16, u_common_modes=74, p_common_modes=50, u_used=74, p_used=50
# $8 \times 8$: u_regions=64, p_regions=64, u_common_modes=29, p_common_modes=22, u_used=29, p_used=22

# %%
import json
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D


def _leaf_p_cap(reg):
    p_cap = reg.get("P_cap_leaf", None)
    if p_cap is not None:
        return int(p_cap)

    n_mu = reg.get("n_mu_train", None)
    if n_mu is None:
        return None

    n_mu = int(n_mu)
    return max(0, int(np.floor(np.sqrt(n_mu))) - 1) if n_mu > 0 else 0


def is_requested_P_valid_for_all_leaves(payload, P_value):
    regions = payload.get("pod_spectra", {}).get("regions", {})
    if not regions:
        return True

    p_req = int(P_value)
    for reg in regions.values():
        p_cap = _leaf_p_cap(reg)
        if p_cap is None:
            continue
        if p_req > p_cap:
            return False
    return True


def filter_valid_P_values(payload, P_values):
    P_values = np.asarray(P_values, dtype=int)
    if P_values.size == 0:
        return P_values
    mask = np.array([is_requested_P_valid_for_all_leaves(payload, p) for p in P_values], dtype=bool)
    return P_values[mask]


def filter_valid_P_series(payload, P_values, *arrays):
    P_values = np.asarray(P_values, dtype=int)
    if P_values.size == 0:
        outs = [P_values]
        outs.extend(np.asarray(a) for a in arrays)
        return tuple(outs)

    mask = np.array([is_requested_P_valid_for_all_leaves(payload, p) for p in P_values], dtype=bool)
    outs = [P_values[mask]]
    for arr in arrays:
        arr = np.asarray(arr)
        m = min(len(arr), len(mask))
        outs.append(arr[:m][mask[:m]])
    return tuple(outs)


def assert_requested_P_within_leaf_caps(payload, P_value):
    p_req = int(P_value)
    if is_requested_P_valid_for_all_leaves(payload, p_req):
        return p_req
    print(f"Skipping invalid/capped P={p_req} (exceeds leaf admissible degree).")
    return None


def validate_no_silent_capped_models(payload):
    # Non-failing by design: plotting code filters invalid P points explicitly.
    return



def format_tau_math(tau):
    s = f"{tau:.15e}"
    mantissa, exponent = s.split("e")
    mantissa = mantissa.rstrip("0").rstrip(".")
    return rf"10^{{{int(exponent)}}}"


def average_r_components_per_tau(run, tau_list):
    out = {}
    res = run["results"]
    for tau in tau_list:
        tau_key = str(tau)
        block = res.get(tau_key, {})

        r_p_list = np.asarray(block.get("r_p", []), dtype=float)
        r_u_stab_list = np.asarray(block.get("r_u", []), dtype=float)

        if len(r_p_list) == 0 or len(r_u_stab_list) == 0:
            out[tau] = None
            continue

        # Stored r_u is stabilized velocity size (velocity + supremizers).
        # Using r_s = r_p and r_u = r_u_stab - r_s gives r = [r_p, r_u, r_s].
        r_p = float(np.mean(r_p_list))
        r_s = r_p
        r_u = float(np.mean(r_u_stab_list - r_s))
        out[tau] = (r_p, r_u, r_s)
    return out

def format_r_value(r):
    return f"{r:.2f}".rstrip("0").rstrip(".")

def format_r_triplet(vals):
    if vals is None:
        return "N/A"
    r_p, r_u, r_s = vals
    return f"[{format_r_value(r_p)},{format_r_value(r_u)},{format_r_value(r_s)}]"

def average_r_tot_per_tau(run, tau_list):
    out = {}
    res = run["results"]
    for tau in tau_list:
        tau_key = str(tau)
        block = res.get(tau_key, {})
        r_tot_list = np.asarray(block.get("r_tot", []), dtype=float)

        if len(r_tot_list) > 0:
            out[tau] = float(np.mean(r_tot_list))
            continue

        comps = average_r_components_per_tau(run, [tau]).get(tau)
        out[tau] = float(sum(comps)) if comps is not None else None
    return out

def format_r_tot_value(r_tot):
    return "N/A" if r_tot is None else format_r_value(r_tot)


# ------------------------------------------------------------
# Load runs
# ------------------------------------------------------------
paths = [
    (r"$1\times 1$", "results_nsplit1.json"),
    (r"$2\times 2$", "results_nsplit2.json"),
    (r"$4\times 4$", "results_nsplit4.json"),
    (r"$8\times 8$", "results_nsplit8.json"),
]

runs = []
for name, path in paths:
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)
    validate_no_silent_capped_models(data)
    runs.append({
        "name": name,
        "cfg": data.get("config", {}),
        "results": data.get("results", {}),
        "payload": data,
    })

if not runs:
    raise ValueError("No runs loaded.")

tau_list = [float(t) for t in runs[0]["cfg"]["tau_list"]]


# ------------------------------------------------------------
# Plot helper: one panel per Nsplit, one curve per tau
# ------------------------------------------------------------
def plot_speedup_grid(
    runs,
    tau_list,
    speedup_key,
    ylabel="Speedup",
    yscale=None,
    panel_width=4.8,
    panel_height=5.2,
    savepath=None,
):
    nplots = len(runs)
    if nplots == 4:
        nrows, ncols = 2, 2
    else:
        ncols = min(3, nplots)
        nrows = math.ceil(nplots / ncols)

    fig, axes = plt.subplots(
        nrows, ncols,
        figsize=(panel_width * ncols, panel_height * nrows),
        sharex=True,
        sharey=True,
        squeeze=False,
    )
    axes = axes.ravel()

    for ax in axes[nplots:]:
        ax.set_visible(False)

    for idx, (ax, run) in enumerate(zip(axes, runs)):
        results = run["results"]
        r_tot_dict = average_r_tot_per_tau(run, tau_list)
        is_single_domain = run["cfg"].get("Nsplit", 1) == 1

        ax.set_title(run["name"])
        ax.grid(True, which="both", ls="--", alpha=0.4)

        if yscale:
            ax.set_yscale(yscale)

        row = idx // ncols
        col = idx % ncols
        if row == nrows - 1:
            ax.set_xlabel(r"Polynomial degree $P$")
        if col == 0:
            ax.set_ylabel(ylabel)

        for tau in tau_list:
            tau_key = str(tau)
            if tau_key not in results:
                continue

            Pvals = np.asarray(results[tau_key].get("P", []), dtype=int)
            sp = np.asarray(results[tau_key].get(speedup_key, []), dtype=float)

            if Pvals.size == 0 or sp.size == 0:
                continue

            m = min(Pvals.size, sp.size)
            Pvals = Pvals[:m]
            sp = sp[:m]
            Pvals, sp = filter_valid_P_series(run["payload"], Pvals, sp)
            if Pvals.size == 0:
                continue

            tau_math = format_tau_math(tau)
            ax.plot(
                Pvals,
                sp,
                marker="o",
                label=rf"$r={format_r_tot_value(r_tot_dict[tau])}$",
            )

        ax.legend(loc="best", frameon=True)

    fig.tight_layout()

    if savepath is not None:
        fig.savefig(savepath, dpi=300, bbox_inches="tight")

    plt.show()


# ------------------------------------------------------------
# Baseline ROM speedup (FOM/ROM)
# ------------------------------------------------------------
savepath = "figs/baseline_speedup.pdf"
plot_speedup_grid(
    runs=runs,
    tau_list=tau_list,
    speedup_key="rom_speedup_throughput",
    ylabel=r"Speed-up (FOM/ROM)",
    yscale=None,
    savepath=savepath,
)

# ------------------------------------------------------------
# CoSTA ROM speedup (FOM/CoSTA)
# ------------------------------------------------------------
savepath = "figs/costa_speedup.pdf"
plot_speedup_grid(
    runs=runs,
    tau_list=tau_list,
    speedup_key="costa_speedup_throughput",
    ylabel=r"Speed-up (FOM/CoSTA)",
    yscale=None,
    savepath=savepath
)

# %%
# do all at the same time

def plot_multi_error_improvement_grid(
    runs,
    tau_list,
    metric_triplets,
    ylabel=r"Improvement factor",
    yscale=None,
    panel_width=4.8,
    panel_height=5.2,
    savepath=None,
    clamp_min=0.1,
    clamp_max=100.0,
):
    nplots = len(runs)
    if nplots == 4:
        nrows, ncols = 2, 2
    else:
        ncols = min(3, nplots)
        nrows = math.ceil(nplots / ncols)

    fig, axes = plt.subplots(
        nrows, ncols,
        figsize=(panel_width * ncols, panel_height * nrows),
        sharex=True,
        sharey=True,
        squeeze=False,
    )
    axes = axes.ravel()

    for ax in axes[nplots:]:
        ax.set_visible(False)

    tau_color_map = {tau: f"C{i}" for i, tau in enumerate(tau_list)}

    style_map = {
        "u_l2": ("-", "o"),
        "u_khdiv": ("--", "s"),
        "p_l2": (":", "x"),
    }

    for idx, (ax, run) in enumerate(zip(axes, runs)):
        results = run["results"]

        ax.set_title(run["name"])
        ax.grid(True, which="both", ls="--", alpha=0.4)
        ax.axhline(1.0, color="black", lw=1.0, ls=":", alpha=0.8)

        # if yscale:
        #     ax.set_yscale(yscale)
        # else:
        #     ax.set_ylim(clamp_min, clamp_max)
        ax.set_yscale(yscale)
        ax.set_ylim(clamp_min, clamp_max)

        row = idx // ncols
        col = idx % ncols
        if row == nrows - 1:
            ax.set_xlabel(r"Polynomial degree $P$")
        if col == 0:
            ax.set_ylabel(ylabel)

        for tau in tau_list:
            tau_key = str(tau)
            if tau_key not in results:
                continue

            block = results[tau_key]
            Pvals_raw = np.asarray(block.get("P", []), dtype=int)
            if Pvals_raw.size == 0:
                continue

            for metric_name, baseline_key, costa_key in metric_triplets:
                baseline_err = np.asarray(block.get(baseline_key, []), dtype=float)
                costa_err = np.asarray(block.get(costa_key, []), dtype=float)

                if baseline_err.size == 0 or costa_err.size == 0:
                    continue

                m = min(Pvals_raw.size, baseline_err.size, costa_err.size)
                Pvals = Pvals_raw[:m]
                baseline_err = baseline_err[:m]
                costa_err = costa_err[:m]

                ratio = np.full(m, np.nan, dtype=float)
                mask = np.isfinite(baseline_err) & np.isfinite(costa_err) & (costa_err != 0.0)
                ratio[mask] = baseline_err[mask] / costa_err[mask]

                Pvals, ratio = filter_valid_P_series(run["payload"], Pvals, ratio)
                finite = np.isfinite(ratio)
                Pvals = Pvals[finite]
                ratio = ratio[finite]
                if Pvals.size == 0:
                    continue

                ls, mk = style_map.get(metric_name, ("-", "o"))
                ax.plot(
                    Pvals,
                    ratio,
                    linestyle=ls,
                    marker=mk,
                    color=tau_color_map[tau],
                    linewidth=1.8,
                    markersize=4.5,
                )

        # Legend 1: tau colors with r-triplet (inside axes)
        r_comp_dict = average_r_components_per_tau(run, tau_list)
        is_single_domain = run["cfg"].get("Nsplit", 1) == 1
        r_symbol = "=" if is_single_domain else r"\approx"
        tau_handles = [
            Line2D([0], [0], color=tau_color_map[tau], lw=2,
                #    label=rf"$\tau={format_tau_math(tau)}$, $r={format_r_triplet(r_comp_dict[tau])}$")
                   label=rf"$\tau={format_tau_math(tau)}(r{r_symbol}{format_r_triplet(r_comp_dict[tau])})$")
            for i, tau in enumerate(tau_list)
        ]
        leg_tau = ax.legend(handles=tau_handles, loc="lower right", frameon=True, fontsize=13)

        ax.add_artist(leg_tau)


    metric_handles = [
        Line2D([0], [0], color="black", linestyle=style_map[m][0], marker=style_map[m][1], lw=2, label=lbl)
        for m, lbl in [("u_l2", r"$\|e_{\mathbf{u}}\|_{L^2(\Omega)}$"), ("u_khdiv", r"$\|e_{\mathbf{u}}\|_{E(\Omega)}$"), ("p_l2", r"$\|e_p\|_{L^2(\Omega)}$")]
    ]
    fig.legend(
        handles=metric_handles,
        loc="upper center",
        ncol=3,
        frameon=True,
        fontsize=16,
        bbox_to_anchor=(0.53,1.0),
    )

    fig.tight_layout(rect=(0, 0, 1, 0.95))

    if savepath is not None:
        fig.savefig(savepath, dpi=300, bbox_inches="tight")

    plt.show()


# velocity_metric_triplets = [
#     ("u_l2", "baseline_u_l2_scaled_maxt_mean", "costa_u_l2_scaled_maxt_mean"),
#     ("p_l2", "baseline_p_l2_scaled_maxt_mean", "costa_p_l2_scaled_maxt_mean"),
#     ("u_khdiv", "baseline_u_khdiv_scaled_maxt_mean", "costa_u_khdiv_scaled_maxt_mean"),
# ]
velocity_metric_triplets = [
    ("u_l2", "baseline_u_l2_scaled_maxt_max", "costa_u_l2_scaled_maxt_max"),
    ("p_l2", "baseline_p_l2_scaled_maxt_max", "costa_p_l2_scaled_maxt_max"),
    ("u_khdiv", "baseline_u_khdiv_scaled_maxt_max", "costa_u_khdiv_scaled_maxt_max"),
]

savepath = "figs/baseline_vs_costa_all_velocity_errors_scaled_maxt_mean_stationary.pdf"
plot_multi_error_improvement_grid(
    runs=runs,
    tau_list=tau_list,
    metric_triplets=velocity_metric_triplets,
    ylabel=r"Error reduction factor (ROM/CoSTA)",
    yscale="log",
    savepath=savepath,
)

# %%
# experiment plot
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.legend_handler import HandlerTuple
from matplotlib.patches import Patch


def plot_error_vs_speedup_scatter_grid(
    runs,
    error_key_baseline="baseline_u_khdiv_scaled_l2t_mean",
    error_key_costa="costa_u_khdiv_scaled_l2t_mean",
    speedup_key_baseline="rom_speedup_throughput",
    speedup_key_costa="costa_speedup_throughput",
    yscale="log",
    ymin=1e-5,
    ymax=1.0,
    panel_width=4.8,
    panel_height=5.2,
    savepath=None,
):
    nplots = len(runs)
    if nplots == 4:
        nrows, ncols = 2, 2
    else:
        ncols = min(3, nplots)
        nrows = int(np.ceil(nplots / ncols))

    fig, axes = plt.subplots(
        nrows, ncols,
        figsize=(panel_width * ncols, panel_height * nrows),
        sharex=True,
        sharey=True,
        squeeze=False,
    )
    axes = axes.ravel()

    for ax in axes[nplots:]:
        ax.set_visible(False)

    # Global P-color map so colors are consistent across all subplots
    all_P = set()
    for run in runs:
        for tau_key, block in run["results"].items():
            all_P.update(np.asarray(block.get("P", []), dtype=int).tolist())
    P_sorted = sorted(all_P)
    p_color = {p: f"C{i % 10}" for i, p in enumerate(P_sorted)}

    tau_sorted_desc = sorted(tau_list, reverse=True)
    tau_shapes = ["o", "^", "s"]
    tau_shape_names = ["Circle", "Triangle", "Square"]
    tau_marker = {tau: tau_shapes[min(i, len(tau_shapes)-1)] for i, tau in enumerate(tau_sorted_desc)}
    tau_shape_name = {tau: tau_shape_names[min(i, len(tau_shape_names)-1)] for i, tau in enumerate(tau_sorted_desc)}

    for idx, (ax, run) in enumerate(zip(axes, runs)):
        ax.set_title(run["name"])

        row = idx // ncols
        col = idx % ncols
        if row == nrows - 1:
            ax.set_xlabel("Speed-up")
        if col == 0:
            ax.set_ylabel("Relative energy error")

        for tau in tau_list:
            tau_key = str(tau)
            if tau_key not in run["results"]:
                continue
            block = run["results"][tau_key]

            Pvals = np.asarray(block.get("P", []), dtype=int)
            e_base = np.asarray(block.get(error_key_baseline, []), dtype=float)
            e_costa = np.asarray(block.get(error_key_costa, []), dtype=float)
            s_base = np.asarray(block.get(speedup_key_baseline, []), dtype=float)
            s_costa = np.asarray(block.get(speedup_key_costa, []), dtype=float)

            m = min(Pvals.size, e_base.size, e_costa.size, s_base.size, s_costa.size)
            if m == 0:
                continue

            Pvals = Pvals[:m]
            e_base = e_base[:m]
            e_costa = e_costa[:m]
            s_base = s_base[:m]
            s_costa = s_costa[:m]

            Pvals, e_base, e_costa, s_base, s_costa = filter_valid_P_series(
                run["payload"], Pvals, e_base, e_costa, s_base, s_costa
            )

            good_base = np.isfinite(e_base) & np.isfinite(s_base) & (e_base > 0) & (s_base > 0)
            good_costa = np.isfinite(e_costa) & np.isfinite(s_costa) & (e_costa > 0) & (s_costa > 0)

            for p in np.unique(Pvals[good_base]):
                sel = good_base & (Pvals == p)
                ax.scatter(s_base[sel], e_base[sel], marker=tau_marker[tau], s=34, color=p_color[int(p)], alpha=0.9)

            for p in np.unique(Pvals[good_costa]):
                sel = good_costa & (Pvals == p)
                ax.scatter(
                    s_costa[sel],
                    e_costa[sel],
                    marker=tau_marker[tau],
                    s=42,
                    facecolors="none",
                    edgecolors=p_color[int(p)],
                    linewidths=0.5,
                    alpha=0.95,
                )


        r_comp_dict = average_r_components_per_tau(run, tau_list)
        is_single_domain = run["cfg"].get("Nsplit", 1) == 1
        r_symbol = "=" if is_single_domain else r"\approx"
        tau_handles = [
            Line2D(
                [0], [0],
                marker=tau_marker[tau],
                color="black",
                markerfacecolor="black",
                linestyle="None",
                markersize=7,
                label=rf"$\tau={format_tau_math(tau)}$ $(r{r_symbol}{format_r_triplet(r_comp_dict[tau])})$",
            )
            for tau in tau_sorted_desc
        ]
        leg_tau = ax.legend(handles=tau_handles, loc="best", frameon=True, fontsize=13,framealpha=0.1)
        ax.add_artist(leg_tau)

        ax.set_yscale(yscale)
        ax.set_ylim(ymin, ymax)
        ax.grid(True, which="both", ls="--", alpha=0.35)

    baseline_triplet = (
        Line2D([0], [0], marker="o", color="black", markerfacecolor="black", linestyle="None", markersize=6),
        Line2D([0], [0], marker="^", color="black", markerfacecolor="black", linestyle="None", markersize=6),
        Line2D([0], [0], marker="s", color="black", markerfacecolor="black", linestyle="None", markersize=6),
    )
    costa_triplet = (
        Line2D([0], [0], marker="o", color="black", markerfacecolor="none", linestyle="None", markersize=6),
        Line2D([0], [0], marker="^", color="black", markerfacecolor="none", linestyle="None", markersize=6),
        Line2D([0], [0], marker="s", color="black", markerfacecolor="none", linestyle="None", markersize=6),
    )

    method_handles = [baseline_triplet, costa_triplet]
    method_labels = ["Baseline ROM", "ROM + CoSTA"]

    degree_handles = [
        Patch(facecolor=p_color[p], edgecolor=p_color[p], label=rf"$P={p}$")
        for p in P_sorted
    ]
    fig.legend(
        handles=method_handles,
        labels=method_labels,
        handler_map={tuple: HandlerTuple(ndivide=None, pad=0.2)},
        loc="upper left",
        ncol=1,
        frameon=True,
        fontsize=13,
        bbox_to_anchor=(0.1, 0.98),
    )

    fig.legend(
        handles=degree_handles,
        loc="upper center",
        ncol=5,
        frameon=True,
        fontsize=13,
        bbox_to_anchor=(0.65, 0.98),
    )

    fig.tight_layout(rect=(0, 0, 1, 0.92))

    if savepath is not None:
        fig.savefig(savepath, dpi=300, bbox_inches="tight")

    plt.show()


plot_error_vs_speedup_scatter_grid(
    runs=runs,
    error_key_baseline="baseline_u_khdiv_scaled_l2t_mean",
    error_key_costa="costa_u_khdiv_scaled_l2t_mean",
    speedup_key_baseline="rom_speedup_throughput",
    speedup_key_costa="costa_speedup_throughput",
    yscale="log",
    ymin=1e-4,
    ymax=1.0,
    savepath="figs/error_vs_speedup_scatter.pdf",
)

# %%
# import json
# import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib.patches import Rectangle
# from matplotlib.colors import ListedColormap, Normalize
# from matplotlib.cm import ScalarMappable


# # ============================================================
# # Helpers
# # ============================================================
# def scaled_dist(mu_a, mu_b, a_mu, b_mu):
#     sx = float(b_mu - a_mu)
#     sy = float(b_mu - a_mu)
#     xa = (float(mu_a[0]) - a_mu) / sx
#     ya = (float(mu_a[1]) - a_mu) / sy
#     xb = (float(mu_b[0]) - a_mu) / sx
#     yb = (float(mu_b[1]) - a_mu) / sy
#     return float(np.sqrt((xa - xb) ** 2 + (ya - yb) ** 2))


# def classify_mu_anchor_tree(mu, nodes, root_id, a_mu, b_mu):
#     cur = root_id
#     while True:
#         node = nodes[cur]
#         is_leaf = bool(node.get("is_leaf", True))
#         anchor1 = node.get("anchor1", None)
#         left_id = node.get("left_id", None)
#         right_id = node.get("right_id", None)

#         if is_leaf or anchor1 is None or left_id is None or right_id is None:
#             return cur

#         anchor0 = tuple(node["anchor0"])
#         anchor1 = tuple(anchor1)

#         d0 = scaled_dist(mu, anchor0, a_mu, b_mu)
#         d1 = scaled_dist(mu, anchor1, a_mu, b_mu)

#         if d0 < d1:
#             cur = left_id
#         else:
#             cur = right_id


# def get_leaf_centroid_from_mu_train(node, fallback_x, fallback_y):
#     mus = node.get("mu_train", [])
#     if mus:
#         mx = float(np.mean([m[0] for m in mus]))
#         my = float(np.mean([m[1] for m in mus]))
#         return mx, my
#     return fallback_x, fallback_y


# def get_leaf_mode_counts(leaf_id, pod_regions, rom_ranks, tau_key, P_key, source="raw"):
#     if source == "raw":
#         reg = pod_regions.get(leaf_id, {})
#         ru = reg.get("u_raw_r_by_tau", {}).get(str(tau_key), None)
#         rp = reg.get("p_r_by_tau", {}).get(str(tau_key), None)

#         ru = None if ru is None else int(ru)
#         rp = None if rp is None else int(rp)
#         rt = None if (ru is None or rp is None) else int(ru + rp)
#         return ru, rp, rt

#     if source == "rom":
#         block = rom_ranks.get(str(tau_key), {}).get(str(P_key), {}).get(leaf_id, {})
#         ru = block.get("r_u", None)
#         rp = block.get("r_p", None)
#         rt = block.get("r_tot", None)

#         ru = None if ru is None else int(ru)
#         rp = None if rp is None else int(rp)
#         rt = None if rt is None else int(rt)
#         return ru, rp, rt

#     raise ValueError(f"Unknown source={source!r}")


# def build_leaf_label_lines(leaf_id, depth, ru, rp, rt, show_ids=False, show_depth=False, label_mode="total"):
#     lines = []
#     if show_ids:
#         lines.append(str(leaf_id))
#     if show_depth:
#         lines.append(f"d={depth}")

#     if label_mode == "u":
#         if ru is not None:
#             lines.append(f"u={ru}")
#     elif label_mode == "p":
#         if rp is not None:
#             lines.append(f"p={rp}")
#     elif label_mode == "total":
#         if rt is not None:
#             lines.append(f"{rt}")
#     elif label_mode == "all":
#         if ru is not None:
#             lines.append(f"u={ru}")
#         if rp is not None:
#             lines.append(f"p={rp}")
#         if rt is not None:
#             lines.append(f"tot={rt}")

#     return lines


# def compute_leaf_value_map(leaf_ids_sorted, pod_regions, rom_ranks, tau_key, P_key, mode, source="raw"):
#     value_map = {}
#     for leaf_id in leaf_ids_sorted:
#         ru, rp, rt = get_leaf_mode_counts(
#             leaf_id, pod_regions, rom_ranks, tau_key, P_key, source=source
#         )
#         if mode == "u":
#             value_map[leaf_id] = np.nan if ru is None else float(ru)
#         elif mode == "p":
#             value_map[leaf_id] = np.nan if rp is None else float(rp)
#         elif mode == "total":
#             value_map[leaf_id] = np.nan if rt is None else float(rt)
#         else:
#             value_map[leaf_id] = np.nan
#     return value_map


# def make_title(json_path, partition_mode, color_mode, tau_show, P_show, rank_source):
#     src = "true ROM dimensions" if rank_source == "rom" else "raw POD dimensions"

#     if partition_mode == "rect":
#         if color_mode == "leaf":
#             return f"Rectangular parameter partition\n{json_path}"
#         return (
#             f"Rectangular parameter partition colored by {color_mode} ({src})\n"
#             f"tau={tau_show}, P={P_show}, file={json_path}"
#         )

#     if color_mode == "leaf":
#         return f"Anchor-tree parameter regions\n{json_path}"

#     return (
#         f"Anchor-tree parameter regions colored by {color_mode} ({src})\n"
#         f"tau={tau_show}, P={P_show}, file={json_path}"
#     )


# def load_payload(json_path):
#     with open(json_path, "r", encoding="utf-8") as f:
#         payload = json.load(f)
#     validate_no_silent_capped_models(payload)
#     return payload


# def _leaf_p_cap(reg):
#     p_cap = reg.get("P_cap_leaf", None)
#     if p_cap is not None:
#         return int(p_cap)

#     n_mu = reg.get("n_mu_train", None)
#     if n_mu is None:
#         return None

#     n_mu = int(n_mu)
#     return max(0, int(np.floor(np.sqrt(n_mu))) - 1) if n_mu > 0 else 0


# def is_requested_P_valid_for_all_leaves(payload, P_value):
#     regions = payload.get("pod_spectra", {}).get("regions", {})
#     if not regions:
#         return True

#     p_req = int(P_value)
#     for reg in regions.values():
#         p_cap = _leaf_p_cap(reg)
#         if p_cap is None:
#             continue
#         if p_req > p_cap:
#             return False
#     return True


# def filter_valid_P_values(payload, P_values):
#     P_values = np.asarray(P_values, dtype=int)
#     if P_values.size == 0:
#         return P_values
#     mask = np.array([is_requested_P_valid_for_all_leaves(payload, p) for p in P_values], dtype=bool)
#     return P_values[mask]


# def filter_valid_P_series(payload, P_values, *arrays):
#     P_values = np.asarray(P_values, dtype=int)
#     if P_values.size == 0:
#         outs = [P_values]
#         outs.extend(np.asarray(a) for a in arrays)
#         return tuple(outs)

#     mask = np.array([is_requested_P_valid_for_all_leaves(payload, p) for p in P_values], dtype=bool)
#     outs = [P_values[mask]]
#     for arr in arrays:
#         arr = np.asarray(arr)
#         m = min(len(arr), len(mask))
#         outs.append(arr[:m][mask[:m]])
#     return tuple(outs)


# def assert_requested_P_within_leaf_caps(payload, P_value):
#     p_req = int(P_value)
#     if is_requested_P_valid_for_all_leaves(payload, p_req):
#         return p_req
#     print(f"Skipping invalid/capped P={p_req} (exceeds leaf admissible degree).")
#     return None


# def validate_no_silent_capped_models(payload):
#     # Non-failing by design: plotting code filters invalid P points explicitly.
#     return


# def build_coloring(leaf_ids_sorted, pod_regions, rom_ranks, tau_show, P_show, color_mode, rank_source):
#     sm = None

#     if color_mode == "leaf":
#         leaf_to_int = {leaf_id: i for i, leaf_id in enumerate(leaf_ids_sorted)}
#         base_colors = list(plt.cm.tab20.colors)
#         reps = (len(leaf_ids_sorted) // len(base_colors)) + 2
#         cmap = ListedColormap((base_colors * reps)[:max(1, len(leaf_ids_sorted))])

#         def facecolor_for_leaf(leaf_id):
#             return cmap(leaf_to_int[leaf_id])

#         return facecolor_for_leaf, sm, None, None

#     if color_mode in {"u", "p", "total"}:
#         leaf_value_map = compute_leaf_value_map(
#             leaf_ids_sorted,
#             pod_regions,
#             rom_ranks,
#             tau_show,
#             P_show,
#             color_mode,
#             source=rank_source,
#         )
#         valid_vals = [v for v in leaf_value_map.values() if np.isfinite(v)]
#         if not valid_vals:
#             raise ValueError(
#                 f"No valid per-leaf values found for color_mode={color_mode!r}, "
#                 f"tau={tau_show!r}, P={P_show!r}, source={rank_source!r}."
#             )

#         vmin = float(min(valid_vals))
#         vmax = float(max(valid_vals))
#         if abs(vmax - vmin) < 1e-14:
#             vmax = vmin + 1.0

#         cmap = plt.cm.viridis
#         norm = Normalize(vmin=vmin, vmax=vmax)

#         def facecolor_for_leaf(leaf_id):
#             return cmap(norm(leaf_value_map[leaf_id]))

#         sm = ScalarMappable(norm=norm, cmap=cmap)
#         sm.set_array([])
#         return facecolor_for_leaf, sm, leaf_value_map, norm

#     raise ValueError(f"Unknown color_mode={color_mode!r}")


# def add_colorbar(fig, ax, sm, rank_source, color_mode, tau_show, P_show):
#     if sm is None:
#         return

#     cbar = fig.colorbar(sm, ax=ax, shrink=0.85)

#     if rank_source == "rom":
#         if color_mode == "u":
#             cbar.set_label(f"true ROM velocity dimension at tau={tau_show}, P={P_show}")
#         elif color_mode == "p":
#             cbar.set_label(f"true ROM pressure dimension at tau={tau_show}, P={P_show}")
#         elif color_mode == "total":
#             cbar.set_label(f"true ROM total dimension at tau={tau_show}, P={P_show}")
#     else:
#         if color_mode == "u":
#             cbar.set_label(f"raw velocity POD modes at tau={tau_show}")
#         elif color_mode == "p":
#             cbar.set_label(f"pressure POD modes at tau={tau_show}")
#         elif color_mode == "total":
#             cbar.set_label(f"raw total POD modes at tau={tau_show}")


# # ============================================================
# # Plotters
# # ============================================================
# def plot_rect_partition(
#     ax,
#     fig,
#     payload,
#     json_path,
#     tau_show="0.001",
#     P_show="5",
#     rank_source="rom",
#     label_mode="total",
#     color_mode="total",
#     show_ids=False,
#     show_depth=False,
# ):
#     partition = payload.get("partition", {})
#     config = payload.get("config", {})
#     pod_regions = payload.get("pod_spectra", {}).get("regions", {})
#     rom_ranks = payload.get("rom_ranks", {})

#     a_mu = float(config.get("a_mu", 0.0))
#     b_mu = float(config.get("b_mu", 1.0))

#     leaves = partition.get("leaves", {})
#     if not leaves:
#         raise ValueError("No partition/leaves found in JSON.")

#     leaf_ids_sorted = sorted(leaves.keys())

#     facecolor_for_leaf, sm, _, _ = build_coloring(
#         leaf_ids_sorted, pod_regions, rom_ranks, tau_show, P_show, color_mode, rank_source
#     )

#     for leaf_id, leaf in leaves.items():
#         ax0 = float(leaf["ax"])
#         bx = float(leaf["bx"])
#         ay = float(leaf["ay"])
#         by = float(leaf["by"])
#         depth = int(leaf.get("depth", 0))

#         w = bx - ax0
#         h = by - ay

#         rect = Rectangle(
#             (ax0, ay),
#             w,
#             h,
#             fill=True,
#             facecolor=facecolor_for_leaf(leaf_id),
#             edgecolor="black",
#             linewidth=1.2,
#             alpha=0.35,
#         )
#         ax.add_patch(rect)

#         cx = 0.5 * (ax0 + bx)
#         cy = 0.5 * (ay + by)

#         ru, rp, rt = get_leaf_mode_counts(
#             leaf_id, pod_regions, rom_ranks, tau_show, P_show, source=rank_source
#         )
#         label_lines = build_leaf_label_lines(
#             leaf_id, depth, ru, rp, rt,
#             show_ids=show_ids, show_depth=show_depth, label_mode=label_mode
#         )

#         if label_lines:
#             ax.text(
#                 cx, cy,
#                 "\n".join(label_lines),
#                 ha="center", va="center",
#                 fontsize=32,
#                 bbox=dict(boxstyle="round,pad=0.2", fc="white", alpha=0.7, ec="none"),
#             )

#     ax.set_title(make_title(json_path, "rect", color_mode, tau_show, P_show, rank_source))
#     add_colorbar(fig, ax, sm, rank_source, color_mode, tau_show, P_show)

#     return a_mu, b_mu


# def plot_anchor_tree_partition(
#     ax,
#     fig,
#     payload,
#     json_path,
#     tau_show="0.001",
#     P_show="5",
#     rank_source="rom",
#     label_mode="total",
#     color_mode="total",
#     show_ids=False,
#     show_depth=False,
#     show_anchors=False,
#     grid_n=300,
# ):
#     partition = payload.get("partition", {})
#     config = payload.get("config", {})
#     pod_regions = payload.get("pod_spectra", {}).get("regions", {})
#     rom_ranks = payload.get("rom_ranks", {})

#     a_mu = float(config.get("a_mu", 0.0))
#     b_mu = float(config.get("b_mu", 1.0))

#     nodes = partition.get("nodes", {})
#     root_id = partition.get("root_id", None)
#     leaf_ids = partition.get("leaf_ids", [])

#     if not nodes or root_id is None:
#         raise ValueError("Anchor-tree partition found, but nodes/root_id missing.")

#     xs = np.linspace(a_mu, b_mu, grid_n)
#     ys = np.linspace(a_mu, b_mu, grid_n)
#     XX, YY = np.meshgrid(xs, ys)

#     leaf_ids_sorted = sorted(leaf_ids)

#     if color_mode == "leaf":
#         leaf_to_int = {leaf_id: i for i, leaf_id in enumerate(leaf_ids_sorted)}
#         Z = np.empty_like(XX, dtype=int)

#         for i in range(grid_n):
#             for j in range(grid_n):
#                 mu = (float(XX[i, j]), float(YY[i, j]))
#                 leaf_id = classify_mu_anchor_tree(mu, nodes, root_id, a_mu, b_mu)
#                 Z[i, j] = leaf_to_int[leaf_id]

#         base_colors = list(plt.cm.tab20.colors)
#         reps = (len(leaf_ids_sorted) // len(base_colors)) + 2
#         cmap = ListedColormap((base_colors * reps)[:max(1, len(leaf_ids_sorted))])

#         ax.pcolormesh(XX, YY, Z, shading="auto", cmap=cmap, alpha=0.35)
#         sm = None

#     elif color_mode in {"u", "p", "total"}:
#         leaf_value_map = compute_leaf_value_map(
#             leaf_ids_sorted,
#             pod_regions,
#             rom_ranks,
#             tau_show,
#             P_show,
#             color_mode,
#             source=rank_source,
#         )
#         valid_vals = [v for v in leaf_value_map.values() if np.isfinite(v)]
#         if not valid_vals:
#             raise ValueError(
#                 f"No valid per-leaf values found for color_mode={color_mode!r}, "
#                 f"tau={tau_show!r}, P={P_show!r}, source={rank_source!r}."
#             )

#         vmin = float(min(valid_vals))
#         vmax = float(max(valid_vals))
#         if abs(vmax - vmin) < 1e-14:
#             vmax = vmin + 1.0

#         cmap = plt.cm.viridis
#         norm = Normalize(vmin=vmin, vmax=vmax)
#         Z = np.empty_like(XX, dtype=float)

#         for i in range(grid_n):
#             for j in range(grid_n):
#                 mu = (float(XX[i, j]), float(YY[i, j]))
#                 leaf_id = classify_mu_anchor_tree(mu, nodes, root_id, a_mu, b_mu)
#                 Z[i, j] = leaf_value_map[leaf_id]

#         ax.pcolormesh(XX, YY, Z, shading="auto", cmap=cmap, norm=norm, alpha=0.35)
#         sm = ScalarMappable(norm=norm, cmap=cmap)
#         sm.set_array([])

#     else:
#         raise ValueError(f"Unknown color_mode={color_mode!r}")

#     fallback_x = float(np.mean(xs))
#     fallback_y = float(np.mean(ys))

#     for leaf_id in leaf_ids_sorted:
#         node = nodes[leaf_id]
#         depth = int(node.get("depth", 0))
#         mx, my = get_leaf_centroid_from_mu_train(node, fallback_x, fallback_y)

#         ru, rp, rt = get_leaf_mode_counts(
#             leaf_id, pod_regions, rom_ranks, tau_show, P_show, source=rank_source
#         )
#         label_lines = build_leaf_label_lines(
#             leaf_id, depth, ru, rp, rt,
#             show_ids=show_ids, show_depth=show_depth, label_mode=label_mode
#         )

#         if label_lines:
#             ax.text(
#                 mx, my,
#                 "\n".join(label_lines),
#                 ha="center", va="center",
#                 fontsize=16,
#                 bbox=dict(boxstyle="round,pad=0.2", fc="white", alpha=0.75, ec="none"),
#             )

#     if show_anchors:
#         for _, node in nodes.items():
#             anchor0 = node.get("anchor0", None)
#             anchor1 = node.get("anchor1", None)
#             is_leaf = bool(node.get("is_leaf", True))

#             if anchor0 is not None:
#                 ax.plot(anchor0[0], anchor0[1], "ko", markersize=4)

#             if anchor1 is not None:
#                 ax.plot(anchor1[0], anchor1[1], "k^", markersize=4)

#             if (not is_leaf) and (anchor0 is not None) and (anchor1 is not None):
#                 ax.plot(
#                     [anchor0[0], anchor1[0]],
#                     [anchor0[1], anchor1[1]],
#                     "k--",
#                     linewidth=0.8,
#                     alpha=0.7,
#                 )

#     ax.set_title(make_title(json_path, "anchor", color_mode, tau_show, P_show, rank_source))
#     add_colorbar(fig, ax, sm, rank_source, color_mode, tau_show, P_show)

#     return a_mu, b_mu


# def plot_partition(
#     json_path,
#     tau_show="0.001",
#     P_show="5",
#     rank_source="rom",
#     label_mode="total",
#     color_mode="total",
#     show_ids=False,
#     show_depth=False,
#     show_mu_test=False,
#     show_anchors=False,
#     grid_n=300,
#     figsize=(8, 8),
# ):
#     payload = load_payload(json_path)
#     P_show = assert_requested_P_within_leaf_caps(payload, P_show)
#     if P_show is None:
#         print(f"Skipping plot_partition for invalid requested P.")
#         return
#     partition = payload.get("partition", {})
#     config = payload.get("config", {})

#     a_mu = float(config.get("a_mu", 0.0))
#     b_mu = float(config.get("b_mu", 1.0))

#     fig, ax = plt.subplots(figsize=figsize)

#     if partition.get("mode") == "rect" or (
#         "leaves" in partition and isinstance(partition.get("leaves"), dict)
#     ):
#         a_mu, b_mu = plot_rect_partition(
#             ax=ax,
#             fig=fig,
#             payload=payload,
#             json_path=json_path,
#             tau_show=tau_show,
#             P_show=P_show,
#             rank_source=rank_source,
#             label_mode=label_mode,
#             color_mode=color_mode,
#             show_ids=show_ids,
#             show_depth=show_depth,
#         )

#     elif partition.get("mode") == "anchor_tree":
#         a_mu, b_mu = plot_anchor_tree_partition(
#             ax=ax,
#             fig=fig,
#             payload=payload,
#             json_path=json_path,
#             tau_show=tau_show,
#             P_show=P_show,
#             rank_source=rank_source,
#             label_mode=label_mode,
#             color_mode=color_mode,
#             show_ids=show_ids,
#             show_depth=show_depth,
#             show_anchors=show_anchors,
#             grid_n=grid_n,
#         )

#     else:
#         raise ValueError("Unknown partition format in JSON.")

#     mu_test = payload.get("mu_test", [])
#     if show_mu_test and mu_test:
#         xt = [mu[0] for mu in mu_test]
#         yt = [mu[1] for mu in mu_test]
#         ax.scatter(xt, yt, s=10, c="black", alpha=0.6, label="mu_test")

#     ax.set_xlim(a_mu, b_mu)
#     ax.set_ylim(a_mu, b_mu)
#     ax.set_xlabel(r"$\mu_x$")
#     ax.set_ylabel(r"$\mu_y$")
#     ax.set_aspect("equal")
#     ax.grid(True, alpha=0.3)

#     if show_mu_test and mu_test:
#         ax.legend(loc="best")

#     plt.tight_layout()
#     plt.show()


# # ============================================================
# json_path = "results_stationary_nsplit8.json"
# # json_path = "results_nsplit8.json"
# # json_path = "results_adaptive_5e5.json"
# tau_show = "0.0005"
# P_show = "7"

# rank_source = "rom"      # "raw" or "rom"
# label_mode = "total"     # "none", "u", "p", "total", "all"
# color_mode = "total"     # "leaf", "u", "p", "total"

# show_ids = False
# show_depth = False
# show_mu_test = False
# show_anchors = False
# grid_n = 300


# plot_partition(
#     json_path=json_path,
#     tau_show=tau_show,
#     P_show=P_show,
#     rank_source=rank_source,
#     label_mode=label_mode,
#     color_mode=color_mode,
#     show_ids=show_ids,
#     show_depth=show_depth,
#     show_mu_test=show_mu_test,
#     show_anchors=show_anchors,
#     grid_n=grid_n,
# )

# %%
# import json
# import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib.patches import Rectangle
# from matplotlib.colors import Normalize


# # ============================================================
# # Metric alias handling
# # ============================================================
# def normalize_metric_name(metric_name):
#     aliases = {
#         "baseline_p_maxt": "baseline_p_l2_abs_maxt",
#         "baseline_p_l2t": "baseline_p_l2_abs_l2t",
#         "costa_p_maxt": "costa_p_l2_abs_maxt",
#         "costa_p_l2t": "costa_p_l2_abs_l2t",

#         "baseline_u_maxt": "baseline_u_l2_abs_maxt",
#         "baseline_u_l2t": "baseline_u_l2_abs_l2t",
#         "costa_u_maxt": "costa_u_l2_abs_maxt",
#         "costa_u_l2t": "costa_u_l2_abs_l2t",

#         "baseline_u_l2_maxt": "baseline_u_l2_abs_maxt",
#         "baseline_u_l2_l2t": "baseline_u_l2_abs_l2t",
#         "costa_u_l2_maxt": "costa_u_l2_abs_maxt",
#         "costa_u_l2_l2t": "costa_u_l2_abs_l2t",

#         "baseline_p_l2_maxt": "baseline_p_l2_abs_maxt",
#         "baseline_p_l2_l2t": "baseline_p_l2_abs_l2t",
#         "costa_p_l2_maxt": "costa_p_l2_abs_maxt",
#         "costa_p_l2_l2t": "costa_p_l2_abs_l2t",

#         "baseline_u_hdiv_maxt": "baseline_u_hdiv_abs_maxt",
#         "baseline_u_hdiv_l2t": "baseline_u_hdiv_abs_l2t",
#         "costa_u_hdiv_maxt": "costa_u_hdiv_abs_maxt",
#         "costa_u_hdiv_l2t": "costa_u_hdiv_abs_l2t",

#         "baseline_u_khdiv_maxt": "baseline_u_khdiv_abs_maxt",
#         "baseline_u_khdiv_l2t": "baseline_u_khdiv_abs_l2t",
#         "costa_u_khdiv_maxt": "costa_u_khdiv_abs_maxt",
#         "costa_u_khdiv_l2t": "costa_u_khdiv_abs_l2t",
#     }
#     return aliases.get(metric_name, metric_name)


# # ============================================================
# # Helpers
# # ============================================================
# def load_payload(json_path):
#     with open(json_path, "r", encoding="utf-8") as f:
#         payload = json.load(f)
#     validate_no_silent_capped_models(payload)
#     return payload


# def _leaf_p_cap(reg):
#     p_cap = reg.get("P_cap_leaf", None)
#     if p_cap is not None:
#         return int(p_cap)

#     n_mu = reg.get("n_mu_train", None)
#     if n_mu is None:
#         return None

#     n_mu = int(n_mu)
#     return max(0, int(np.floor(np.sqrt(n_mu))) - 1) if n_mu > 0 else 0


# def is_requested_P_valid_for_all_leaves(payload, P_value):
#     regions = payload.get("pod_spectra", {}).get("regions", {})
#     if not regions:
#         return True

#     p_req = int(P_value)
#     for reg in regions.values():
#         p_cap = _leaf_p_cap(reg)
#         if p_cap is None:
#             continue
#         if p_req > p_cap:
#             return False
#     return True


# def filter_valid_P_values(payload, P_values):
#     P_values = np.asarray(P_values, dtype=int)
#     if P_values.size == 0:
#         return P_values
#     mask = np.array([is_requested_P_valid_for_all_leaves(payload, p) for p in P_values], dtype=bool)
#     return P_values[mask]


# def filter_valid_P_series(payload, P_values, *arrays):
#     P_values = np.asarray(P_values, dtype=int)
#     if P_values.size == 0:
#         outs = [P_values]
#         outs.extend(np.asarray(a) for a in arrays)
#         return tuple(outs)

#     mask = np.array([is_requested_P_valid_for_all_leaves(payload, p) for p in P_values], dtype=bool)
#     outs = [P_values[mask]]
#     for arr in arrays:
#         arr = np.asarray(arr)
#         m = min(len(arr), len(mask))
#         outs.append(arr[:m][mask[:m]])
#     return tuple(outs)


# def assert_requested_P_within_leaf_caps(payload, P_value):
#     p_req = int(P_value)
#     if is_requested_P_valid_for_all_leaves(payload, p_req):
#         return p_req
#     print(f"Skipping invalid/capped P={p_req} (exceeds leaf admissible degree).")
#     return None


# def validate_no_silent_capped_models(payload):
#     # Non-failing by design: plotting code filters invalid P points explicitly.
#     return


# def scaled_dist(mu_a, mu_b, a_mu, b_mu):
#     sx = float(b_mu - a_mu)
#     sy = float(b_mu - a_mu)

#     xa = (float(mu_a[0]) - a_mu) / sx
#     ya = (float(mu_a[1]) - a_mu) / sy
#     xb = (float(mu_b[0]) - a_mu) / sx
#     yb = (float(mu_b[1]) - a_mu) / sy

#     return float(np.sqrt((xa - xb) ** 2 + (ya - yb) ** 2))


# def classify_mu_anchor_tree(mu, nodes, root_id, a_mu, b_mu):
#     cur = root_id

#     while True:
#         node = nodes[cur]

#         is_leaf = bool(node.get("is_leaf", True))
#         anchor1 = node.get("anchor1", None)
#         left_id = node.get("left_id", None)
#         right_id = node.get("right_id", None)

#         if is_leaf or anchor1 is None or left_id is None or right_id is None:
#             return cur

#         anchor0 = tuple(node["anchor0"])
#         anchor1 = tuple(anchor1)

#         d0 = scaled_dist(mu, anchor0, a_mu, b_mu)
#         d1 = scaled_dist(mu, anchor1, a_mu, b_mu)

#         if d0 < d1:
#             cur = left_id
#         else:
#             cur = right_id


# def classify_mu_rect(mu, leaves):
#     mx, my = float(mu[0]), float(mu[1])

#     for leaf_id, leaf in leaves.items():
#         ax = float(leaf["ax"])
#         bx = float(leaf["bx"])
#         ay = float(leaf["ay"])
#         by = float(leaf["by"])

#         in_x = (ax <= mx < bx) or np.isclose(mx, bx)
#         in_y = (ay <= my < by) or np.isclose(my, by)

#         if in_x and in_y:
#             return leaf_id

#     raise RuntimeError(f"Could not classify mu={mu} in rectangular partition")


# def classify_mu(mu, partition, a_mu, b_mu):
#     mode = partition.get("mode", None)

#     if mode == "anchor_tree":
#         return classify_mu_anchor_tree(
#             mu,
#             partition["nodes"],
#             partition["root_id"],
#             a_mu,
#             b_mu,
#         )

#     if mode == "rect" or ("leaves" in partition and isinstance(partition.get("leaves"), dict)):
#         return classify_mu_rect(mu, partition["leaves"])

#     raise ValueError(f"Unknown partition mode: {mode!r}")


# def get_partition_leaf_ids(partition):
#     mode = partition.get("mode", None)

#     if mode == "anchor_tree":
#         return sorted(partition.get("leaf_ids", []))

#     if mode == "rect" or ("leaves" in partition and isinstance(partition.get("leaves"), dict)):
#         return sorted(partition["leaves"].keys())

#     raise ValueError(f"Unknown partition mode: {mode!r}")


# def extract_metric_entry(payload, tau_key, Pdeg):
#     res_tau = payload["results"][str(tau_key)]

#     for e in res_tau["per_mu"]:
#         if int(e["P"]) == int(Pdeg):
#             return e

#     return None


# def region_label_positions(partition, a_mu, b_mu):
#     mode = partition.get("mode", None)
#     pos = {}

#     if mode == "rect" or ("leaves" in partition and isinstance(partition.get("leaves"), dict)):
#         for leaf_id, leaf in partition["leaves"].items():
#             cx = 0.5 * (float(leaf["ax"]) + float(leaf["bx"]))
#             cy = 0.5 * (float(leaf["ay"]) + float(leaf["by"]))
#             pos[leaf_id] = (cx, cy)
#         return pos

#     if mode == "anchor_tree":
#         xs = [a_mu, b_mu]
#         ys = [a_mu, b_mu]
#         fallback_x = float(np.mean(xs))
#         fallback_y = float(np.mean(ys))

#         for leaf_id in sorted(partition["leaf_ids"]):
#             node = partition["nodes"][leaf_id]
#             mus = node.get("mu_train", [])
#             if mus:
#                 mx = float(np.mean([m[0] for m in mus]))
#                 my = float(np.mean([m[1] for m in mus]))
#             else:
#                 mx, my = fallback_x, fallback_y
#             pos[leaf_id] = (mx, my)
#         return pos

#     raise ValueError(f"Unknown partition mode: {mode!r}")


# # ============================================================
# # Background plotting
# # ============================================================
# def plot_partition_background(ax, partition, a_mu, b_mu, grid_n=300, alpha=0.25):
#     mode = partition.get("mode", None)

#     if mode == "rect" or ("leaves" in partition and isinstance(partition.get("leaves"), dict)):
#         leaves = partition["leaves"]
#         leaf_ids_sorted = sorted(leaves.keys())
#         leaf_to_int = {leaf_id: i for i, leaf_id in enumerate(leaf_ids_sorted)}
#         cmap = plt.cm.tab20

#         for leaf_id, leaf in leaves.items():
#             ax0 = float(leaf["ax"])
#             bx = float(leaf["bx"])
#             ay = float(leaf["ay"])
#             by = float(leaf["by"])

#             rect = Rectangle(
#                 (ax0, ay),
#                 bx - ax0,
#                 by - ay,
#                 facecolor=cmap(leaf_to_int[leaf_id] % cmap.N),
#                 edgecolor="black",
#                 linewidth=1.0,
#                 alpha=alpha,
#             )
#             ax.add_patch(rect)
#         return

#     if mode == "anchor_tree":
#         nodes = partition["nodes"]
#         root_id = partition["root_id"]
#         leaf_ids_sorted = sorted(partition["leaf_ids"])
#         leaf_to_int = {leaf_id: i for i, leaf_id in enumerate(leaf_ids_sorted)}

#         xs = np.linspace(a_mu, b_mu, grid_n)
#         ys = np.linspace(a_mu, b_mu, grid_n)
#         XX, YY = np.meshgrid(xs, ys)
#         Z = np.zeros_like(XX, dtype=int)

#         for i in range(grid_n):
#             for j in range(grid_n):
#                 mu = (float(XX[i, j]), float(YY[i, j]))
#                 leaf_id = classify_mu_anchor_tree(mu, nodes, root_id, a_mu, b_mu)
#                 Z[i, j] = leaf_to_int[leaf_id]

#         ax.pcolormesh(
#             XX,
#             YY,
#             Z,
#             shading="auto",
#             cmap=plt.cm.tab20,
#             alpha=alpha,
#         )
#         return

#     raise ValueError(f"Unknown partition mode: {mode!r}")


# def plot_anchors(ax, partition):
#     if partition.get("mode") != "anchor_tree":
#         return

#     nodes = partition["nodes"]

#     for node in nodes.values():
#         anchor0 = node.get("anchor0", None)
#         anchor1 = node.get("anchor1", None)
#         is_leaf = bool(node.get("is_leaf", True))

#         if anchor0 is not None:
#             ax.plot(anchor0[0], anchor0[1], "ko", markersize=4)

#         if anchor1 is not None:
#             ax.plot(anchor1[0], anchor1[1], "k^", markersize=4)

#         if (not is_leaf) and (anchor0 is not None) and (anchor1 is not None):
#             ax.plot(
#                 [anchor0[0], anchor1[0]],
#                 [anchor0[1], anchor1[1]],
#                 "k--",
#                 linewidth=0.8,
#                 alpha=0.7,
#             )


# # ============================================================
# # Main plotter
# # ============================================================
# def plot_metric_over_partition(
#     json_path,
#     tau_key="0.001",
#     Pdeg=6,
#     metric="costa_u_l2_scaled_maxt",
#     show_mu_test=False,
#     show_error_labels=False,
#     show_anchors=False,
#     show_leaf_ids=False,
#     grid_n=300,
#     figsize=(8, 8),
# ):
#     payload = load_payload(json_path)
#     Pdeg = assert_requested_P_within_leaf_caps(payload, Pdeg)
#     if Pdeg is None:
#         print("Skipping plot_metric_over_partition: requested P is invalid/capped.")
#         return
#     metric = normalize_metric_name(metric)

#     config = payload["config"]
#     partition = payload["partition"]

#     a_mu = float(config["a_mu"])
#     b_mu = float(config["b_mu"])

#     entry = extract_metric_entry(payload, tau_key, Pdeg)
#     if entry is None:
#         print(f"No valid entry found for tau={tau_key}, P={Pdeg}; skipping plot.")
#         return
#     data = entry["data"]

#     mus = np.array([d["mu"] for d in data], dtype=float)
#     vals = np.array([d[metric] for d in data], dtype=float)

#     x = mus[:, 0]
#     y = mus[:, 1]

#     fig, ax = plt.subplots(figsize=figsize)

#     # background regions
#     plot_partition_background(
#         ax=ax,
#         partition=partition,
#         a_mu=a_mu,
#         b_mu=b_mu,
#         grid_n=grid_n,
#         alpha=0.25,
#     )

#     # optional anchors
#     if show_anchors:
#         plot_anchors(ax, partition)

#     # scatter metric values
#     norm = Normalize(vmin=float(vals.min()), vmax=float(vals.max()))

#     sc = ax.scatter(
#         x,
#         y,
#         c=vals,
#         cmap="plasma",
#         norm=norm,
#         s=70,
#         edgecolor="black",
#     )

#     cbar = fig.colorbar(sc, ax=ax)
#     cbar.set_label(metric)

#     # optional numeric point labels
#     if show_error_labels:
#         for xi, yi, vi in zip(x, y, vals):
#             ax.text(
#                 xi,
#                 yi,
#                 f"{vi:.2e}",
#                 fontsize=7,
#                 ha="center",
#                 va="center",
#                 color="black",
#             )

#     # optional leaf ids
#     if show_leaf_ids:
#         pos = region_label_positions(partition, a_mu, b_mu)
#         for leaf_id, (lx, ly) in pos.items():
#             ax.text(
#                 lx,
#                 ly,
#                 str(leaf_id),
#                 fontsize=8,
#                 ha="center",
#                 va="center",
#                 bbox=dict(boxstyle="round,pad=0.2", fc="white", alpha=0.7, ec="none"),
#             )

#     # optional mu_test overlay
#     mu_test = payload.get("mu_test", [])
#     if show_mu_test and mu_test:
#         xt = [mu[0] for mu in mu_test]
#         yt = [mu[1] for mu in mu_test]
#         ax.scatter(xt, yt, s=10, c="black", alpha=0.6, label="mu_test")
#         ax.legend(loc="best")

#     mode = partition.get("mode", "unknown")
#     ax.set_title(f"{metric} over {mode} domains\n tau={tau_key}, P={Pdeg}, file={json_path}")

#     ax.set_xlim(a_mu, b_mu)
#     ax.set_ylim(a_mu, b_mu)
#     ax.set_xlabel(r"$\mu_x$")
#     ax.set_ylabel(r"$\mu_y$")
#     ax.set_aspect("equal")
#     ax.grid(True, alpha=0.3)

#     plt.tight_layout()
#     plt.show()


# # ============================================================
# json_path = "results_stationary_nsplit8.json"
# # json_path = "results_nsplit8.json"

# tau_key = "0.001"
# Pdeg = 7

# # metric = "baseline_u_l2_scaled_maxt"
# metric = "baseline_u_l2_scaled_maxt"

# show_mu_test = False
# show_error_labels = False
# show_anchors = False
# show_leaf_ids = False

# grid_n = 300


# plot_metric_over_partition(
#     json_path=json_path,
#     tau_key=tau_key,
#     Pdeg=Pdeg,
#     metric=metric,
#     show_mu_test=show_mu_test,
#     show_error_labels=show_error_labels,
#     show_anchors=show_anchors,
#     show_leaf_ids=show_leaf_ids,
#     grid_n=grid_n,
# )

# %%
# import json
# import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib.colors import Normalize


# def _leaf_p_cap(reg):
#     p_cap = reg.get("P_cap_leaf", None)
#     if p_cap is not None:
#         return int(p_cap)

#     n_mu = reg.get("n_mu_train", None)
#     if n_mu is None:
#         return None

#     n_mu = int(n_mu)
#     return max(0, int(np.floor(np.sqrt(n_mu))) - 1) if n_mu > 0 else 0


# def is_requested_P_valid_for_all_leaves(payload, P_value):
#     regions = payload.get("pod_spectra", {}).get("regions", {})
#     if not regions:
#         return True

#     p_req = int(P_value)
#     for reg in regions.values():
#         p_cap = _leaf_p_cap(reg)
#         if p_cap is None:
#             continue
#         if p_req > p_cap:
#             return False
#     return True


# def filter_valid_P_values(payload, P_values):
#     P_values = np.asarray(P_values, dtype=int)
#     if P_values.size == 0:
#         return P_values
#     mask = np.array([is_requested_P_valid_for_all_leaves(payload, p) for p in P_values], dtype=bool)
#     return P_values[mask]


# def filter_valid_P_series(payload, P_values, *arrays):
#     P_values = np.asarray(P_values, dtype=int)
#     if P_values.size == 0:
#         outs = [P_values]
#         outs.extend(np.asarray(a) for a in arrays)
#         return tuple(outs)

#     mask = np.array([is_requested_P_valid_for_all_leaves(payload, p) for p in P_values], dtype=bool)
#     outs = [P_values[mask]]
#     for arr in arrays:
#         arr = np.asarray(arr)
#         m = min(len(arr), len(mask))
#         outs.append(arr[:m][mask[:m]])
#     return tuple(outs)


# def assert_requested_P_within_leaf_caps(payload, P_value):
#     p_req = int(P_value)
#     if is_requested_P_valid_for_all_leaves(payload, p_req):
#         return p_req
#     print(f"Skipping invalid/capped P={p_req} (exceeds leaf admissible degree).")
#     return None


# def validate_no_silent_capped_models(payload):
#     # Non-failing by design: plotting code filters invalid P points explicitly.
#     return


# # ============================================================
# # USER INPUT
# # ============================================================

# json_path = "results_stationary_nsplit8.json"

# tau_key = "0.001"
# Pdeg = 7

# baseline_metric = "baseline_u_l2_scaled_maxt"
# costa_metric    = "costa_u_l2_scaled_maxt"

# show_mu_test = False
# show_error_labels = False
# show_anchors = False

# grid_n = 300

# # ============================================================
# # Helper functions
# # ============================================================

# def scaled_dist(mu_a, mu_b, a_mu, b_mu):
#     sx = b_mu - a_mu
#     sy = b_mu - a_mu

#     xa = (mu_a[0] - a_mu) / sx
#     ya = (mu_a[1] - a_mu) / sy
#     xb = (mu_b[0] - a_mu) / sx
#     yb = (mu_b[1] - a_mu) / sy

#     return np.sqrt((xa - xb) ** 2 + (ya - yb) ** 2)


# def classify_mu_anchor_tree(mu, nodes, root_id, a_mu, b_mu):
#     cur = root_id

#     while True:
#         node = nodes[cur]

#         if node.get("is_leaf", True):
#             return cur

#         anchor0 = tuple(node["anchor0"])
#         anchor1 = tuple(node["anchor1"])

#         d0 = scaled_dist(mu, anchor0, a_mu, b_mu)
#         d1 = scaled_dist(mu, anchor1, a_mu, b_mu)

#         if d0 < d1:
#             cur = node["left_id"]
#         else:
#             cur = node["right_id"]


# def classify_mu_rect(mu, leaves):
#     mx, my = float(mu[0]), float(mu[1])

#     for leaf_id, leaf in leaves.items():
#         ax = float(leaf["ax"])
#         bx = float(leaf["bx"])
#         ay = float(leaf["ay"])
#         by = float(leaf["by"])

#         in_x = (ax <= mx < bx) or np.isclose(mx, bx)
#         in_y = (ay <= my < by) or np.isclose(my, by)

#         if in_x and in_y:
#             return leaf_id

#     raise RuntimeError(f"Could not classify mu={mu} in rectangular partition")


# def classify_mu_partition(mu, partition, a_mu, b_mu):
#     mode = partition.get("mode", "anchor_tree")

#     if mode == "anchor_tree":
#         return classify_mu_anchor_tree(
#             mu=mu,
#             nodes=partition["nodes"],
#             root_id=partition["root_id"],
#             a_mu=a_mu,
#             b_mu=b_mu,
#         )

#     if mode == "rect":
#         return classify_mu_rect(mu=mu, leaves=partition["leaves"])

#     raise RuntimeError(f"Unknown partition mode: {mode}")


# def get_partition_leaf_ids(partition):
#     if "leaf_ids" in partition:
#         return partition["leaf_ids"]

#     mode = partition.get("mode", "anchor_tree")
#     if mode == "anchor_tree":
#         return list(partition["nodes"].keys())
#     if mode == "rect":
#         return list(partition["leaves"].keys())

#     raise RuntimeError(f"Unknown partition mode: {mode}")


# # ============================================================
# # Load JSON
# # ============================================================

# with open(json_path, "r", encoding="utf-8") as f:
#     payload = json.load(f)
# validate_no_silent_capped_models(payload)
# Pdeg = assert_requested_P_within_leaf_caps(payload, Pdeg)

# config = payload["config"]
# partition = payload["partition"]

# a_mu = float(config["a_mu"])
# b_mu = float(config["b_mu"])

# # ============================================================
# # Extract per-mu data
# # ============================================================

# res_tau = payload["results"][tau_key]

# entry = None
# if Pdeg is not None:
#     for e in res_tau["per_mu"]:
#         if int(e["P"]) == int(Pdeg):
#             entry = e
#             break

# if entry is None:
#     print(f"Skipping plotting points for tau={tau_key}, P={Pdeg} (invalid/capped or missing).")
#     data = []
#     mus = np.empty((0, 2), dtype=float)
#     baseline_vals = np.array([], dtype=float)
#     costa_vals = np.array([], dtype=float)
#     ratio_vals = np.array([], dtype=float)
#     x = np.array([], dtype=float)
#     y = np.array([], dtype=float)
# else:
#     data = entry["data"]

#     mus = np.array([d["mu"] for d in data], dtype=float)
#     baseline_vals = np.array([d[baseline_metric] for d in data], dtype=float)
#     costa_vals = np.array([d[costa_metric] for d in data], dtype=float)

#     # Ratio > 1 means CoSTA is better, ratio < 1 means CoSTA is worse
#     eps = 1e-14
#     ratio_vals = baseline_vals / np.maximum(costa_vals, eps)

#     print("baseline max =", baseline_vals.max())
#     print("costa max    =", costa_vals.max())
#     print("ratio min    =", ratio_vals.min())
#     print("ratio max    =", ratio_vals.max())

#     x = mus[:, 0]
#     y = mus[:, 1]

# # ============================================================
# # Build partition background grid
# # ============================================================

# leaf_ids = get_partition_leaf_ids(partition)
# leaf_to_int = {leaf: i for i, leaf in enumerate(sorted(leaf_ids))}

# xs = np.linspace(a_mu, b_mu, grid_n)
# ys = np.linspace(a_mu, b_mu, grid_n)
# XX, YY = np.meshgrid(xs, ys)

# Z = np.zeros_like(XX, dtype=float)

# for i in range(grid_n):
#     for j in range(grid_n):
#         mu = (XX[i, j], YY[i, j])
#         leaf = classify_mu_partition(mu, partition, a_mu, b_mu)
#         Z[i, j] = leaf_to_int[leaf]

# # ============================================================
# # Plot
# # ============================================================

# fig, ax = plt.subplots(figsize=(8, 8))

# # background: partition regions
# ax.pcolormesh(
#     XX,
#     YY,
#     Z,
#     shading="auto",
#     cmap=plt.cm.tab20,
#     alpha=0.20
# )

# # color normalization for ratio plot
# if ratio_vals.size > 0:
#     norm = Normalize(vmin=min(1.0, float(ratio_vals.min())), vmax=float(ratio_vals.max()))
# else:
#     norm = Normalize(vmin=0.0, vmax=1.0)

# sc = ax.scatter(
#     x,
#     y,
#     c=ratio_vals,
#     cmap="coolwarm",
#     norm=norm,
#     s=70,
#     edgecolor="black"
# )

# cbar = fig.colorbar(sc, ax=ax)
# cbar.set_label(f"{baseline_metric} / {costa_metric}")

# # optional labels
# if show_error_labels:
#     for xi, yi, vi in zip(x, y, ratio_vals):
#         ax.text(
#             xi, yi, f"{vi:.2e}",
#             fontsize=7,
#             ha="center",
#             va="center",
#             color="black"
#         )

# # optional anchors (only meaningful for anchor_tree)
# if show_anchors and partition.get("mode", "anchor_tree") == "anchor_tree":
#     for node in partition["nodes"].values():
#         if "anchor0" in node and node["anchor0"] is not None:
#             ax.plot(*node["anchor0"], "ko", markersize=4)
#         if node.get("anchor1") is not None:
#             ax.plot(*node["anchor1"], "k^", markersize=5)

# # optional mu_test overlay
# if show_mu_test and "mu_test" in payload:
#     mu_test = np.array(payload["mu_test"], dtype=float)
#     ax.plot(mu_test[:, 0], mu_test[:, 1], "k.", markersize=2, alpha=0.35)

# ax.set_xlim(a_mu, b_mu)
# ax.set_ylim(a_mu, b_mu)
# ax.set_xlabel(r"$\mu_x$")
# ax.set_ylabel(r"$\mu_y$")
# ax.set_aspect("equal")
# ax.grid(True, alpha=0.3)

# mode = partition.get("mode", "anchor_tree")
# # ax.set_title(
# #     "Max-in-time error ratio over parameter domains\n"
# #     f"({baseline_metric} / {costa_metric}, >1 means CoSTA better), "
# #     f"tau={tau_key}, P={Pdeg}, mode={mode}"
# # )

# plt.tight_layout()
# plt.show()
